# %% [markdown]
# # How to use my likelihood calculator
#
# Ben Pennell
#
# --
#
# Max Planck Institut für Astronomie, Heidelberg
# _____

# %%
import numpy as np
import Forward as f
import GaiamockWrapper as gw
import pickle

import matplotlib
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12, 10)
# Out:
# /home/bepennell/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %% [markdown]
# let's create an object using `gaiamock` and then see if we can constrain some of the parameters

# %%
catpath = "data/gaia_catalogue_with_masses.pkl"
r = pickle.load(open(catpath, "rb"))

# %%
set_objs = gw.generate_mock_data(sample_count=10, p_model=(f.calculate_p_distribution, (5,3)), catalogue_with_masses=r, binary_fraction=1, eccentricity=f.calculate_e_distribution)
# Out:
# precomputing all orbital parameters...
# calculating astrometric signals...
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
set_objs
# Out:
# array([{'ra': 271.6513199849765, 'dec': 32.518488923668606, 'parallax': 20.39701881065626, 'iso_mass': 0.5, 'phot_g_mean_mag': 12.463714599609375, 'is_binary': True, 'solution_type': 7, 'acceleration7': 1.3608375799455248, 'acceleration9': 1.379898761200612, 'jerk': 0.6147837987236517, 'period': 5858.248200152536, 'eccentricity': 0.95, 'mass_ratio': 0.8782620435180459, 'inclination': 1.266715856340406, 'omega': 1.5418786749016269, 'Omega': 5.9181526674639935, 't_periastron': 1388.2173268476477, 'ruwe': 2.365995753821561},
#        {'ra': 43.10403111906469, 'dec': -32.97523779012858, 'parallax': 19.730706032480448, 'iso_mass': 0.446, 'phot_g_mean_mag': 13.436412811279297, 'is_binary': True, 'solution_type': 12, 'acceleration7': 33.94273595055022, 'acceleration9': 31.48175119239363, 'jerk': 78.98373458308872, 'period': 1111.849604819271, 'eccentricity': 0.31666666666666665, 'mass_ratio': 0.9332163310688545, 'inclination': 1.3903230628488792, 'omega': 2.108612320636258, 'Omega': 5.403843637776711, 't_periastron': -233.8181454077101, 'ruwe': 37.27292839358802},
#        {'ra': 335.0743437730331, 'dec': -1.6096622052743768, 'parallax': 18.218972853798412, 'iso_mass': 0.45, 'phot_g_mean_mag': 13.242311477661133, 'is_binary': True, 'solution_type': 5, 'acceleration7': 0.09917221775944189, 'acceleration9': 0.055785089113565084, 'jerk': 0.30885824854927074, 'period': 2256074.0664968593, 'eccentricity': 0.44789789789789786, 'mass_ratio': 0.4974345706013654, 'inclination': 0.4468976428914882, 'omega': 2.1477887951756727, 'Omega': 5.299024140944374, 't_periastron': -854560.4877919394, 'ruwe': 1.1764186820192029},
#        {'ra': 177.2604299384795, 'dec': -0.3233347457049638, 'parallax': 29.81188733709847, 'iso_mass': 0.45, 'phot_g_mean_mag': 12.763825416564941, 'is_binary': True, 'solution_type': 5, 'acceleration7': 0.22015317327751058, 'acceleration9': 0.3175691152970219, 'jerk': 0.40387210315483935, 'period': 10.0, 'eccentricity': 0.6333333333333333, 'mass_ratio': 0.0797101780758217, 'inclination': 0.14713968651404932, 'omega': 4.218953544418281, 'Omega': 4.961513304388805, 't_periastron': 0.3093917223503928, 'ruwe': 1.3931271516612134},
#        {'ra': 155.86625104806615, 'dec': -19.36977789531997, 'parallax': 13.919235036885961, 'iso_mass': 0.45, 'phot_g_mean_mag': 13.798759460449219, 'is_binary': True, 'solution_type': 5, 'acceleration7': 0.0602358503826357, 'acceleration9': 0.033388968180282995, 'jerk': 1.2603277455587967, 'period': 100000000.0, 'eccentricity': 0.8957957957957957, 'mass_ratio': 0.010841551945850902, 'inclination': 0.0038949879160692256, 'omega': 1.366903245034552, 'Omega': 5.126683132365407, 't_periastron': 11414116.114000482, 'ruwe': 1.2707475238665615},
#        {'ra': 137.93144404242253, 'dec': -27.13630528876289, 'parallax': 13.556662186493748, 'iso_mass': 0.45, 'phot_g_mean_mag': 13.848420143127441, 'is_binary': True, 'solution_type': 12, 'acceleration7': 7.001305352272416, 'acceleration9': 11.40809128856418, 'jerk': 25.288375439448927, 'period': 152.82140360258708, 'eccentricity': 0.5486986986986987, 'mass_ratio': 0.9421967540560269, 'inclination': 0.7616137083684854, 'omega': 2.383406801864212, 'Omega': 1.1409240216628547, 't_periastron': 23.368386845478515, 'ruwe': 13.55559248251008},
#        {'ra': 100.75758890610987, 'dec': 36.890344172424506, 'parallax': 15.253515429135177, 'iso_mass': 0.5, 'phot_g_mean_mag': 13.7581148147583, 'is_binary': True, 'solution_type': 5, 'acceleration7': 0.595006155216103, 'acceleration9': 0.9924980337237328, 'jerk': 1.6577787684803866, 'period': 114039.96019700331, 'eccentricity': 0.7075075075075075, 'mass_ratio': 0.9372440770345074, 'inclination': 1.551833000857226, 'omega': 2.7709209029538884, 'Omega': 5.479001609106959, 't_periastron': -37785.02810410092, 'ruwe': 1.3525327980551203},
#        {'ra': 333.8146608076471, 'dec': 31.9587166448337, 'parallax': 13.628683626295398, 'iso_mass': 0.543, 'phot_g_mean_mag': 13.552927017211914, 'is_binary': True, 'solution_type': 5, 'acceleration7': 0.4160942450165447, 'acceleration9': 0.4921560483171478, 'jerk': 0.9901385851189713, 'period': 487178.0218794631, 'eccentricity': 0.0, 'mass_ratio': 0.4584248023339932, 'inclination': 0.25294753813227533, 'omega': 5.0099726566044644, 'Omega': 4.367420220046899, 't_periastron': 61221.153070426146, 'ruwe': 1.5636256632430041},
#        {'ra': 281.0156713124329, 'dec': 68.24636004763751, 'parallax': 17.60146340483444, 'iso_mass': 0.5, 'phot_g_mean_mag': 13.482418060302734, 'is_binary': True, 'solution_type': 5, 'acceleration7': 0.07913590364600723, 'acceleration9': 0.029259542053437133, 'jerk': 0.3963279692859019, 'period': 12476595.526308686, 'eccentricity': 0.8377877877877877, 'mass_ratio': 0.34996428237135224, 'inclination': 0.21497751039938945, 'omega': 5.638462630082515, 'Omega': 2.2209656784907073, 't_periastron': 6193936.48599872, 'ruwe': 1.01649663546357},
#        {'ra': 129.12213055180473, 'dec': 22.912014606453894, 'parallax': 27.907122829709337, 'iso_mass': 0.341, 'phot_g_mean_mag': 13.59582233428955, 'is_binary': True, 'solution_type': 9, 'acceleration7': 18.1031852225504, 'acceleration9': 18.17089909272326, 'jerk': 12.62929466255451, 'period': 26694.78494034318, 'eccentricity': 0.7759759759759759, 'mass_ratio': 0.7207708289998564, 'inclination': 0.8774349335843195, 'omega': 3.5498596039672936, 'Omega': 3.9593167043201976, 't_periastron': -6911.9921121870475, 'ruwe': 23.002278428427793}],
#       dtype=object)

# %%
target_object = set_objs[0]

# %% [markdown]
# I've chosen this object. I can now try and constrain the allowed parameters. How this will work is at each RUWE step, it will calculate a distribution of RUWEs considering the noise and marginalised parameters. Then it will determine how often you are within $5\%$ of the correct RUWE value.
#
# In principle I could also see a scheme where you try to minimise the "distance" between the estimated signals and the catalogue ones, instead of the likelihood. This might also be faster. I could implement this if desired.

# %%
target_object
# Out:
# {'ra': 271.6513199849765,
#  'dec': 32.518488923668606,
#  'parallax': 20.39701881065626,
#  'iso_mass': 0.5,
#  'phot_g_mean_mag': 12.463714599609375,
#  'is_binary': True,
#  'solution_type': 7,
#  'acceleration7': 1.3608375799455248,
#  'acceleration9': 1.379898761200612,
#  'jerk': 0.6147837987236517,
#  'period': 5858.248200152536,
#  'eccentricity': 0.95,
#  'mass_ratio': 0.8782620435180459,
#  'inclination': 1.266715856340406,
#  'omega': 1.5418786749016269,
#  'Omega': 5.9181526674639935,
#  't_periastron': 1388.2173268476477,
#  'ruwe': 2.365995753821561}

# %%
my_binary = f.Binary(df=target_object, catalogue_position=True, 
                    m1=target_object["iso_mass"], parallax=target_object["parallax"], ecc=0.95, # 'known' values
                    Tp=gw.random_Tp, w=gw.random_angle, omega=gw.random_angle, # marginalised parameters
                    period={"prior":(1,8)}, q={"prior":(0.01,1)}, inc={"prior":(0,np.pi/2)}) # values to 'constrain'

# %%
my_binary.constrain_parameters(step_count=1000, nwalkers=8, ruwe_sample_count=30)
# Out:
# 100%|██████████| 1000/1000 [06:42<00:00,  2.48it/s]

# %% [markdown]
# let's see how the mcmc 'burn in' took

# %%
my_binary.plot_parameter("period", truth=np.log10(target_object["period"]))

# %% [markdown]
# seems like 500/6 should do

# %%
my_binary.plot_corner(truths=[np.log10(target_object["period"]), target_object["mass_ratio"], target_object["inclination"]], 
                      discard=80);

# %%
my_binary.plot_2d(["period", "q"], truths=[np.log10(target_object["period"]), target_object["mass_ratio"]], discard=60);

# %% [markdown]
# it's doing alright.

# %% [markdown]
# further: you can save the constraining that you've done with
#
# `my_binary.save_results(save_dir="./data", name="binary", note="marginalised orbital angles, constrained p,q,inc")`
#
# and then load a saved object like
#
# `my_binary = f.Catalogue(load="./data/binary.pkl")`
#
# from which you can make plots, constrain parameters, etc.

# %% [markdown]
# there's a lot more little features I have here, you can ask if there's anything else you want to accomplish.
